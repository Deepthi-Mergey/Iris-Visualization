# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings 
warnings.filterwarnings('ignore') # this will ignore the warnings if any and wont display warnings in notebook

# %%
iris = pd.read_csv(r"D:\DS & AI\5th, 6th - Sql workshop\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.shape
# Out:
# (150, 6)

# %% [markdown]
# ** Displaying Data **

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.drop('Id', axis = 1, inplace = True)
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ** Checking if there are any missing values **

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# BAR Plot : Here the frequency of the observation is plotted. In this case, freq of the three species in the Iris Dataset is plotted

# %%
sns.countplot(iris['Species'], palette = sns.color_palette('muted',3), edgecolor = 'darkblue')
plt.show()

# %%
sns.countplot(x = 'Species',data=iris, palette = sns.color_palette('pastel',3), edgecolor = 'darkblue')
plt.show()

# %%
sns.countplot(iris, x = 'Species', hue = 'Species', palette = sns.color_palette('dark',3), edgecolor = 'pink',
             linewidth = 2)
plt.show()

# %% [markdown]
# Each Iris Species in the data set is having 50 samples.

# %% [markdown]
# ** JOINT Plot ** - it is a seaborn library and can be used to quickly visualize and analyse the relationship between two variables
# and describe their individual distributions on the same plot.

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = sns.jointplot(iris, x = 'SepalLengthCm', y = 'SepalWidthCm')

# %%
fig = sns.jointplot(iris, x = 'SepalLengthCm', y = 'SepalWidthCm', kind = 'reg')

# %%
fig = sns.jointplot(iris, x = 'SepalLengthCm', y = 'SepalWidthCm', kind = 'hex')

# %% [markdown]
# ** FACET GRID Plot ** -

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.FacetGrid(iris, hue = 'Species', height = 5)\
.map(plt.scatter, 'SepalLengthCm','SepalWidthCm')\
.add_legend()

# %% [markdown]
# ** BOX or WHISKER Plot ** - gives the statistical summary of the features being plotted.
# - Top line represents the Max value
# - Top edge of box is Third Quartile
# - Middle edge represents the Median
# - Bottom edge represents the First Quartile
# - Bottom line respresents the Minimum value of the feature
# - Height of the box is called as Inter Quartile Range
# - Black dots on the plot represent the outlier values in the data.

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(iris, x ='Species', y ='PetalLengthCm', order = ['Iris-virginica','Iris-versicolor','Iris-setosa'],
                  palette = sns.color_palette('pastel',3),linecolor = 'darkblue', linewidth = 1, orient = 'v', dodge = False)

# %%
iris.boxplot(by="Species", figsize=(12, 6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %% [markdown]
# ** STRIP Plot **

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.stripplot(iris, x = 'Species', y = 'SepalLengthCm', jitter = True,
                  edgecolor = 'black', size = 8, palette = 'winter', orient = 'v')

# %% [markdown]
# ** Combining BOX and STRIP Plots **

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(iris, x = 'Species', y = 'SepalLengthCm', 
                  palette = sns.color_palette('pastel',3), linecolor = 'darkblue', linewidth = 1)
fig = sns.stripplot(iris, x = 'Species', y = 'SepalLengthCm', hue = 'Species', jitter = True, 
                    edgecolor = 'black', linewidth = 0.5, size = 8, palette = 'winter', orient = 'v')

# %%
ax = sns.boxplot(iris, x = "Species", y = "PetalLengthCm", palette = sns.color_palette('pastel',3), 
                 linecolor = 'darkblue', linewidth = 1)
ax = sns.stripplot(iris, x = "Species", y = "PetalLengthCm", hue = 'Species', jitter = True,
                   edgecolor = 'black', linewidth = 0.5, size = 8, palette = 'winter', orient = 'v')

#boxtwo = ax.artists[2]
#boxtwo.set_facecolor('yellow')
#boxtwo.set_edgecolor('black')
#boxthree = ax.artists[1]
#boxthree.set_facecolor('red')
#boxthree.set_edgecolor('black')
#boxthree = ax.artists[0]
#boxthree.set_facecolor('green')
#boxthree.set_edgecolor('black')

plt.show()

# %% [markdown]
# ** VIOLIN Plot ** - It is used to visualize the distribution of data and its probability distribution.
# This chart is a combination of a Box Plot and a Density Plot that is rotated and placed on each side,
# to show the distribution shape of the data.
# - The thick black bar in the centre represents the Inter Quartile Range
# - The thin black line extended from it represents the 95% confidence intervals
# - The white dot is the median
# Box Plots are limited in their display of the data, as their visual simplicity tends to hide significant details
# about how values in the data are distributed

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(iris, x = 'Species', y = 'SepalLengthCm', hue = 'Species')

# %%
plt.figure(figsize = (15,10))
plt.subplot(2,2,1)
sns.violinplot(iris, x = 'Species', y = 'PetalLengthCm', hue = 'Species')
plt.subplot(2,2,2)
sns.violinplot(iris, x = 'Species',y = 'PetalWidthCm', hue = 'Species')
plt.subplot(2,2,3)
sns.violinplot(iris, x = 'Species', y = 'SepalLengthCm', hue = 'Species')
plt.subplot(2,2,4)
sns.violinplot(iris, x = 'Species', y = 'SepalWidthCm', hue = 'Species')
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.pairplot(iris, kind = 'scatter')

# %%
sns.pairplot(iris, hue = 'Species')

# %% [markdown]
# ** HEAT Map ** - it is used to find out the correlation between different features in the dataset.
# High positive or negative value shows that the features have high correlation.This helps us to select the parmeters for machine learning.

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(iris.corr(numeric_only=True), annot = True, cmap = 'cubehelix', 
                  fmt = '.2g', linewidths = 1, linecolor = 'k', square = True, mask = False, 
                  vmin = -1, vmax = 1, cbar_kws = {"orientation" : "vertical"}, cbar = True)

# %% [markdown]
# ** DISTRIBUTION Plot ** - it is suitable for comparing range and distribution of groups having numerical data.
# Data is plotted as value points along an axis. You can choose to display only the value points to see the distribution of values,
# a bounding box to see the range of values, or a combination of both as shown here.
# The distribution plot is not relevant for detailed analysis of the data as it deals with a summary of the data distribution.

# %%
iris.hist(edgecolor = 'black', linewidth = 1.2)
fig = plt.gcf()
fig.set_size_inches(12,6)

# %% [markdown]
# ** SWARM Plot ** - It looks a bit like a friendly swarm of bees buzzing about their hive.
# More importantly, each data point is clearly visible and no data are obscured by overplotting.
# A beeswarm plot improves upon the random jittering approach to move data points the minimum distance away from one another to avoid overlays.
# The result is a plot where you can see each distinct data point, like shown in below plot:

# %%
sns.set(style = "darkgrid")
fig = plt.gcf()
fig.set_size_inches(10,6)
fig = sns.swarmplot(iris, x ="Species", y = "PetalLengthCm", hue = 'Species')

# %%
sns.set(style = "whitegrid")
fig = plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(iris, x = "Species", y = "PetalLengthCm", hue = 'Species', inner = None)
ax = sns.swarmplot(iris, x = "Species", y = "PetalLengthCm", color = "white", edgecolor = "black")

# %% [markdown]
# ** LM Plot **

# %%
fig = sns.lmplot(iris, x = "PetalLengthCm", y = "PetalWidthCm")

# %% [markdown]
# ** FACET GRID Plot **

# %%
sns.FacetGrid(iris, hue = "Species", height = 6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
plt.ioff()

# %% [markdown]
# ** FACTOR Plot **

# %%
#f,ax = plt.subplots(1,2,figsize = (18,8))
sns.factorplot(iris, x = 'Species', y = 'SepalLengthCm')
plt.ioff()
plt.show()
#sns.factorplot(iris, 'Species','SepalLengthCm', ax = ax[0][0])
#sns.factorplot(iris, 'Species','SepalWidthCm', ax = ax[0][1])
#sns.factorplot(iris, 'Species','PetalLengthCm', ax = ax[1][0])
#sns.factorplot(iris, 'Species','PetalWidthCm', ax = ax[1][1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 2
#       1 #f,ax = plt.subplots(1,2,figsize = (18,8))
# ----> 2 sns.factorplot(iris, x = 'Species', y = 'SepalLengthCm')
#       3 plt.ioff()
#       4 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'factorplot'

# %% [markdown]
# ** BOXEN Plot **

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxenplot(iris, x = 'Species', y = 'SepalLengthCm')
plt.show()

# %% [markdown]
# ** KDE Plot **

# %%
# Create a kde plot of sepal_length versus sepal width for setosa species of flower.

sub = iris[iris['Species'] == 'Iris-setosa']
sns.kdeplot(sub, x = 'SepalLengthCm', y = 'SepalWidthCm', color = "g", shade = True, shade_lowest = False)
plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')
plt.show()

# %% [markdown]
# ** Dashboard **

# %%
sns.set_style('darkgrid')
f,axes = plt.subplots(2,2,figsize = (15,15))

k1 = sns.boxplot(iris, x = "Species", y = "PetalLengthCm", ax = axes[0,0])
k2 = sns.violinplot(iris, x = 'Species', y = 'PetalLengthCm', ax = axes[0,1])
k3 = sns.stripplot(iris, x = 'Species', y = 'SepalLengthCm', jitter = True,
                   edgecolor = 'gray', size = 8, palette = 'winter', orient = 'v', ax = axes[1,0])
#axes[1,1].hist(iris.hist,bin=10)
axes[1,1].hist(iris.PetalLengthCm, bins = 100)
#k2.set(xlim=(-1,0.8))
plt.show()

# %% [markdown]
# In the dashboard we have shown how to create multiple plots to foam a dashboard using Python.
# In this plot we have demonstrated how to plot Seaborn and Matplotlib plots on the same Dashboard.

# %% [markdown]
# ** STACKED HISTOGRAM **

# %%
iris['Species'] = iris['Species'].astype('category')

# %%
list1 = list()
mylabels = list()
for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species == gen].SepalLengthCm)
    mylabels.append(gen)
    
h = plt.hist(list1, bins = 30, stacked = True, rwidth = 1, label = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# With Stacked Histogram we can see the distribution of Sepal Length of Different Species together.
# This shows us the range of Sepal Length for the three different Species of Iris Flower.

# %% [markdown]
# ** AREA Plot ** - it gives us a visual representation of Various dimensions of Iris flower and their range in dataset.

# %%
#iris['SepalLengthCm'] = iris['SepalLengthCm'].astype('category')
#iris.head()
#iris.plot.area(y='SepalLengthCm',alpha=0.4,figsize=(12, 6));
iris.plot.area(y = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'], alpha = 0.4, figsize = (12,6))
plt.show()

# %% [markdown]
# ** DIST Plot ** It helps us to look at the distribution of a single variable.
# Kde shows the density of the distribution

# %%
sns.distplot(iris['SepalLengthCm'], kde = True, bins = 20)
plt.show()
